# %% [markdown]
# <a href="https://colab.research.google.com/github/Evelyn-Rojas/Investigaci-n-de-operaciones-7MM1/blob/main/Tarea4_Tablero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color='salmon'> **TAREA 4**
#
# <font color='salmon'> **Evelyn Tania Rojas Roa**
#
# ---

# %% [markdown]
# **Ejercicio:** Supongamos que tenemos un tablero con cuatro sectores, si lanzamos dos monedas y avanzamos en sentidos horario, el numero de caras que aparezcan ** ¿Son todos los sectores igual de probables?**
#
# Casos: CC,CX,XC,XX

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.DiGraph()
G.add_node("R")
G.add_node("A")
G.add_node("V")
G.add_node("R")
G.add_edge("N", "R")
G.add_edge("N", "A")
G.add_edge("R", "V")
G.add_edge("R", "A")
G.add_edge("A", "R")
G.add_edge("V", "N")
G.add_edge("N", "N")
G.add_edge("R", "R")
G.add_edge("A", "A")
G.add_edge("V", "V")
color_map = {
    "N": "darkorange",
    "R": "indianred",
    "A": "lightblue",
    "V": "greenyellow"
}
node_colors = [color_map[node] for node in G.nodes()]
plt.figure(figsize=(4,4))
nx.draw(G,
        with_labels=True,
        node_color=node_colors,
        node_size=2000,
        font_size=15,
        font_weight="bold",
        arrowsize=20,
        edgecolors="black")

# %% [markdown]
# <font color='coral'>**Obtenemos las siguientes ecuaciones:** </font>
# $$
# \begin{aligned}
# X_n &= \tfrac{1}{4}X_(n-1) + 0\cdot Y_(n-1) + \tfrac{1}{4}Z_(n-1) + \tfrac{1}{2}T_(n-1) \\
# Y_n &= \tfrac{1}{2}X_(n-1) + \tfrac{1}{4}Y_(n-1) + 0\cdot Z_(n-1) + \tfrac{1}{4}T_(n-1) \\
# Z_n &= \tfrac{1}{4}X_(n-1) + \tfrac{1}{2}Y_(n-1) + \tfrac{1}{4}Z_(n-1) + 0\cdot T_(n-1) \\
# T_n &= 0\cdot X_(n-1) + \tfrac{1}{4}Y_(n-1) + \tfrac{1}{2}Z_(n-1) + \tfrac{1}{4}T_(n-1)
# \end{aligned}
# $$

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Para ver en que punto nuestra matriz se converge, elevaremos a la potencia n.
# Para el ejercicio se utlizara n=100

# %%
import numpy as np
A = np.array([
    [1/4, 0,   1/4, 1/2],
    [1/2, 1/4, 0,   1/4],
    [1/4, 1/2, 1/4, 0  ],
    [0,   1/4, 1/2, 1/4]
], dtype=float)
print ('Matriz inicial:')
print(A)

def potencia_matriz(A, n): #matriz a la potencia n
    M = np.eye(A.shape[0])
    for _ in range(n):
        M = A @ M
    return M
n = 100
An = potencia_matriz(A, n)
print("-----------------------------------------------")
print(f"Matriz obtenidad con {n} iteraciones (A^{n}):\n")
print(np.round(An, 6))
# Out:
# Matriz inicial:
# [[0.25 0.   0.25 0.5 ]
#  [0.5  0.25 0.   0.25]
#  [0.25 0.5  0.25 0.  ]
#  [0.   0.25 0.5  0.25]]
# -----------------------------------------------
# Matriz obtenidad con 100 iteraciones (A^100):
#
# [[0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]]
